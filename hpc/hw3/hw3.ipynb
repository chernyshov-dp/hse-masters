# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(data={"n_procs": [1, 2, 4, 8, 16, 1, 2, 4, 8, 16],
                        "n_dots": [10000, 10000, 10000, 10000, 10000,  25000, 25000, 25000, 25000, 25000],
                        "time": [2.59782, 1.298910, 0.677499, 0.400671, 0.223909, 67.561963, 30.793184, 8.622599, 4.622481, 2.3112405]})

# %%
plt.xlabel("procs")
plt.ylabel("time")
plt.plot([1, 2, 4, 8, 16], [2.59782, 1.298910, 0.677499, 0.400671, 0.223909], "-")

# %%
plt.xlabel("procs")
plt.ylabel("time")
plt.plot([1, 2, 4, 8, 16], [67.561963, 30.793184, 8.622599, 4.622481, 2.3112405], "-")

# %%
df
# Out:
#     n_procs  n_dots   time
# 0         1   10000  10000
# 1         2   10000  10000
# 2         4   10000  10000
# 3         8   10000  10000
# 4        16   10000  10000
# 5        24   10000  10000
# 6         1   25000  25000
# 7         2   25000  25000
# 8         4   25000  25000
# 9         8   25000  25000
# 10       16   25000  25000
# 11       24   25000  25000
# 12        1   50000  50000
# 13        2   50000  50000
# 14        4   50000  50000
# 15        8   50000  50000
# 16       16   50000  50000
# 17       24   50000  50000
